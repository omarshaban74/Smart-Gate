# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# pip install method
# !pip install ultralytics

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.1/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## Inference with pretraind COCO Moedl

# %%
# %cd {HOME}
# !yolo task=detect mode=predect model=yolo12s.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 917, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {list(MODES)}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=predect'. Valid modes are ['benchmark', 'train', 'export', 'val', 'track', 'predict'].
#
#     Arguments received: ['yolo', 'task=detect', 'mode=predect', 'model=yolo12s.pt', 'conf=0.25', 'source=https://media.roboflow.com/notebooks/examples/dog.jpeg', 'save=True']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ['pose', 'classify', 'detect', 'segment', 'obb']
#                 MODE (required) is one of ['benchmark', 'train', 'export', 'val', 'track', 'predict']
# ...

# %% [markdown]
# ## Custom training

# %%
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="1iZ3sQ7tovb2j2D1uWtw")
project = rf.workspace("depiocrproject").project("yolo13-mjngb")
version = project.version(3)
dataset = version.download("yolov12")
# Out:
# /content/datasets
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.9/89.9 kB 7.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 78.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 107.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.11
#     Uninstalling idna-3.11:
#       Successfully uninstalled idna-3.11
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to yolo13-3 in yolov12:: 100%|██████████| 4076/4076 [00:00<00:00, 7938.53it/s]

# %% [markdown]
# ## Train

# %%
# %cd {HOME}
# !yolo task=detect mode=train model=yolo12s.pt data= /content/datasets/yolo13-3/data.yaml epochs=100 imgsz=640 plots=True
# Out:
# /content
# ...
# Ultralytics 8.3.233 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
